# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.describe()
# Out:
#         Rating       Reviews  Size_MBs
# count 9,367.00     10,841.00 10,841.00
# mean      4.19    444,111.93     19.77
# std       0.52  2,927,628.66     21.40
# min       1.00          0.00      0.01
# 25%       4.00         38.00      4.90
# 50%       4.30      2,094.00     11.00
# 75%       4.50     54,768.00     27.00
# max       5.00 78,158,306.00    100.00

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                                     App     Category  Rating  \
# 6425                                          easyFocus  PHOTOGRAPHY    3.70
# 4560                                          MoodSpace      MEDICAL    4.50
# 7167                       Meet24 - Love, Chat, Singles       DATING    4.20
# 721                                                  FN     BUSINESS    5.00
# 4980  School scientific calculator fx 500 es plus 50...       FAMILY    4.60
#
#       Reviews  Size_MBs   Installs  Type Price Content_Rating       Genres  \
# 6425     3396      0.26    500,000  Free     0       Everyone  Photography
# 4560      503     22.00     50,000  Free     0       Everyone      Medical
# 7167    57081      7.90  1,000,000  Free     0     Mature 17+       Dating
# 721        14      3.30         50  Free     0       Everyone     Business
# 4980     1553      9.20    100,000  Free     0       Everyone    Education
#
#            Last_Updated   Android_Ver
# 6425  November 28, 2012    2.2 and up
# 4560      June 10, 2018    5.0 and up
# 7167      July 27, 2018  4.0.3 and up
# 721    February 1, 2018    4.0 and up
# 4980     August 2, 2018    4.0 and up

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop('Last_Updated', axis=1)
df_apps.drop('Android_Ver', axis=1)
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type   Price Content_Rating  \
# 0             0      8.70              0  Paid  $13.99           Teen
# 1             0     33.00              0  Paid   $2.99       Everyone
# 2             0      5.50              0  Paid   $1.49       Everyone
# 3             0     19.00              0   NaN       0   Everyone 10+
# 4             0     10.00              0  Free       0       Everyone
# ...         ...       ...            ...   ...     ...            ...
# 10836  27723193     76.00  1,000,000,000  Free       0   Everyone 10+
# 10837  27724094     76.00  1,000,000,000  Free       0   Everyone 10+
# 10838  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10839  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10840  27711703     76.00  1,000,000,000  Free       0   Everyone 10+
#
#                 Genres    Last_Updated
# 0               Social   July 28, 2017
# 1            Education  April 15, 2016
# 2      Personalization   July 11, 2018
# 3             Strategy   June 28, 2018
# 4             Business  August 6, 2018
# ...                ...             ...
# 10836           Arcade   July 12, 2018
# 10837           Arcade   July 12, 2018
# 10838           Arcade   July 12, 2018
# 10839           Arcade   July 12, 2018
# 10840           Arcade   July 12, 2018
#
# [10841 rows x 11 columns]

# %%
df_apps.shape
# Out:
# (10841, 12)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.Rating.isna().sum()
# Out:
# np.int64(1474)

# %%
df_apps_clean = df_apps.dropna()

# %%
df_apps_clean.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# Last_Updated      0
# Android_Ver       0
# dtype: int64

# %%
df_apps_clean.shape
# Out:
# (9365, 12)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
# Out:
# np.int64(474)

# %%
df_apps_dup = df_apps_clean[df_apps_clean.duplicated()]
df_apps_dup.shape
# Out:
# (474, 12)

# %%
df_apps_dup.head()
# Out:
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres   Last_Updated  \
# 946      11.00      100  Free       0     Mature 17+  Medical   June 6, 2018
# 1133      3.90      100  Free       0     Mature 17+   Dating  July 17, 2018
# 1196      6.50      100  Paid  $12.99       Everyone  Medical  July 25, 2018
# 1231     22.00      100  Free       0       Everyone  Medical  July 25, 2018
# 1247      4.90      100  Free       0     Mature 17+   Dating  July 24, 2018
#
#        Android_Ver
# 946     4.1 and up
# 1133    4.4 and up
# 1196    3.0 and up
# 1231    5.0 and up
# 1247  4.0.3 and up

# %%
df_apps_dup[df_apps_dup.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10809     0           Teen  Social  July 31, 2018  Varies with device

# %%
df_apps_clean[df_apps_clean.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10806     0           Teen  Social  July 31, 2018  Varies with device
# 10808     0           Teen  Social  July 31, 2018  Varies with device
# 10809     0           Teen  Social  July 31, 2018  Varies with device
# 10810     0           Teen  Social  July 31, 2018  Varies with device

# %%
df_apps_dedup = df_apps_clean.drop_duplicates(keep='first', subset=['App', 'Type', 'Price'])
df_apps_dedup.shape
# Out:
# (8197, 12)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
# These are sorted by Rating
df_apps_dedup.sort_values('Rating', ascending=False)
# Out:
#                                                   App  Category  Rating  \
# 21                                KBA-EZ Health Guide   MEDICAL    5.00
# 126                                   Tablet Reminder   MEDICAL    5.00
# 99    Anatomy & Physiology Vocabulary Exam Review App   MEDICAL    5.00
# 4058                         Ek Bander Ne Kholi Dukan    FAMILY    5.00
# 321                                FK CLASSIC FOR YOU  BUSINESS    5.00
# ...                                               ...       ...     ...
# 818           Familial Hypercholesterolaemia Handbook   MEDICAL    1.00
# 617                                    DT future1 cam     TOOLS    1.00
# 576                                     Clarksburg AH   MEDICAL    1.00
# 357                                 Speech Therapy: F    FAMILY    1.00
# 240                           House party - live chat    DATING    1.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating         Genres  \
# 21          4     25.00        1  Free      0       Everyone        Medical
# 126         4      2.50        5  Free      0       Everyone        Medical
# 99          1      4.60        5  Free      0       Everyone        Medical
# 4058       10      3.00   10,000  Free      0       Everyone  Entertainment
# 321         1      3.50       10  Free      0       Everyone       Business
# ...       ...       ...      ...   ...    ...            ...            ...
# 818         2     33.00      100  Free      0       Everyone        Medical
# 617         1     24.00       50  Free      0       Everyone          Tools
# 576         1     28.00       50  Free      0       Everyone        Medical
# 357         1     16.00       10  Paid  $2.99       Everyone      Education
# 240         1      9.20       10  Free      0     Mature 17+         Dating
#
#            Last_Updated   Android_Ver
# 21       August 2, 2018  4.0.3 and up
# 126      August 3, 2018    4.1 and up
# 99       August 2, 2018    4.0 and up
# 4058      June 26, 2017    4.0 and up
# 321   February 20, 2018    4.0 and up
# ...                 ...           ...
# 818        July 2, 2018    4.1 and up
# 617      March 27, 2018    2.2 and up
# 576         May 1, 2017  4.0.3 and up
# 357     October 7, 2016  2.3.3 and up
# 240       July 31, 2018  4.0.3 and up
#
# [8197 rows x 12 columns]

# %%
# These are sorted by the number of reviews
df_apps_dedup.sort_values('Reviews', ascending=False)
# Out:
#                                             App            Category  Rating  \
# 10805                                  Facebook              SOCIAL    4.10
# 10785                        WhatsApp Messenger       COMMUNICATION    4.40
# 10806                                 Instagram              SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free       COMMUNICATION    4.00
# 10650                            Clash of Clans                GAME    4.60
# ...                                         ...                 ...     ...
# 265                                     FAST EO              EVENTS    5.00
# 576                               Clarksburg AH             MEDICAL    1.00
# 582                                       MI-BP  HEALTH_AND_FITNESS    5.00
# 485                       Familyfirst Messenger             MEDICAL    4.00
# 151                         EB Cash Collections            BUSINESS    5.00
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
# ...         ...       ...            ...   ...   ...            ...
# 265           1      6.30             10  Free     0       Everyone
# 576           1     28.00             50  Free     0       Everyone
# 582           1     12.00             50  Free     0       Everyone
# 485           1      3.30             10  Free     0       Everyone
# 151           1      4.30              5  Free     0       Everyone
#
#                  Genres    Last_Updated         Android_Ver
# 10805            Social  August 3, 2018  Varies with device
# 10785     Communication  August 3, 2018  Varies with device
# 10806            Social   July 31, 2018  Varies with device
# 10784     Communication  August 1, 2018  Varies with device
# 10650          Strategy   July 15, 2018          4.1 and up
# ...                 ...             ...                 ...
# 265              Events    May 15, 2018          4.1 and up
# 576             Medical     May 1, 2017        4.0.3 and up
# 582    Health & Fitness   April 9, 2018          5.0 and up
# 485             Medical   July 12, 2018          4.4 and up
# 151            Business   July 31, 2018          4.4 and up
#
# [8197 rows x 12 columns]

# %%
# These are sorted by the size of the app
df_apps_dedup.sort_values('Size_MBs', ascending=False)
# Out:
#                                                     App            Category  \
# 10295                                   SimCity BuildIt              FAMILY
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 7926                                          Post Bank             FINANCE
# 8718                  Mini Golf King - Multiplayer Game                GAME
# ...                                                 ...                 ...
# 5798                                   ExDialer PRO Key       COMMUNICATION
# 2648                        Ad Remove Plugin for App2SD        PRODUCTIVITY
# 2684                       My baby firework (Remove ad)              FAMILY
# 7966                               Market Update Helper  LIBRARIES_AND_DEMO
# 4696                                Essential Resources  LIBRARIES_AND_DEMO
#
#        Rating  Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 10295    4.50  4218587    100.00  50,000,000  Free      0   Everyone 10+
# 3144     3.60      124    100.00       5,000  Free      0       Everyone
# 4176     3.60      151    100.00      10,000  Free      0       Everyone
# 7926     4.50    60449    100.00   1,000,000  Free      0       Everyone
# 8718     4.50   531458    100.00   5,000,000  Free      0       Everyone
# ...       ...      ...       ...         ...   ...    ...            ...
# 5798     4.50     5474      0.02     100,000  Paid  $3.99       Everyone
# 2648     4.10       66      0.02       1,000  Paid  $1.29       Everyone
# 2684     4.10       30      0.01       1,000  Paid  $0.99       Everyone
# 7966     4.10    20145      0.01   1,000,000  Free      0       Everyone
# 4696     4.60      237      0.01      50,000  Free      0       Everyone
#
#                  Genres        Last_Updated         Android_Ver
# 10295        Simulation       June 19, 2018          4.0 and up
# 3144   Health & Fitness      August 2, 2018          5.0 and up
# 4176             Racing        May 20, 2018          4.1 and up
# 7926            Finance       July 23, 2018          4.0 and up
# 8718             Sports       July 20, 2018        4.0.3 and up
# ...                 ...                 ...                 ...
# 5798      Communication    January 15, 2014          2.1 and up
# 2648       Productivity  September 25, 2013          2.2 and up
# 2684      Entertainment      April 25, 2013  Varies with device
# 7966   Libraries & Demo   February 12, 2013          1.5 and up
# 4696   Libraries & Demo  September 27, 2017          7.1 and up
#
# [8197 rows x 12 columns]

# %%
df_apps_dedup.sort_values('Reviews', ascending=False)
# Out:
#                                             App            Category  Rating  \
# 10805                                  Facebook              SOCIAL    4.10
# 10785                        WhatsApp Messenger       COMMUNICATION    4.40
# 10806                                 Instagram              SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free       COMMUNICATION    4.00
# 10650                            Clash of Clans                GAME    4.60
# ...                                         ...                 ...     ...
# 265                                     FAST EO              EVENTS    5.00
# 576                               Clarksburg AH             MEDICAL    1.00
# 582                                       MI-BP  HEALTH_AND_FITNESS    5.00
# 485                       Familyfirst Messenger             MEDICAL    4.00
# 151                         EB Cash Collections            BUSINESS    5.00
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
# ...         ...       ...            ...   ...   ...            ...
# 265           1      6.30             10  Free     0       Everyone
# 576           1     28.00             50  Free     0       Everyone
# 582           1     12.00             50  Free     0       Everyone
# 485           1      3.30             10  Free     0       Everyone
# 151           1      4.30              5  Free     0       Everyone
#
#                  Genres    Last_Updated         Android_Ver
# 10805            Social  August 3, 2018  Varies with device
# 10785     Communication  August 3, 2018  Varies with device
# 10806            Social   July 31, 2018  Varies with device
# 10784     Communication  August 1, 2018  Varies with device
# 10650          Strategy   July 15, 2018          4.1 and up
# ...                 ...             ...                 ...
# 265              Events    May 15, 2018          4.1 and up
# 576             Medical     May 1, 2017        4.0.3 and up
# 582    Health & Fitness   April 9, 2018          5.0 and up
# 485             Medical   July 12, 2018          4.4 and up
# 151            Business   July 31, 2018          4.4 and up
#
# [8197 rows x 12 columns]

# %%
# Now let's get the first 50, and count how many are paid apps
df_apps_dedup.sort_values('Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# 10770        UC Browser - Fast Download Private & Secure       COMMUNICATION
# 10735                                           Snapchat              SOCIAL
# 10489    360 Security - Free Antivirus, Booster, Cleaner               TOOLS
# 10731                                     My Talking Tom                GAME
# 10594                                        8 Ball Pool                GAME
# 10302  DU Battery Saver - Battery Charger & Battery Life               TOOLS
# 10354                        BBM - Free Calls & Messages       COMMUNICATION
# 10549  Cache Cleaner-DU Speed Booster (booster & clea...               TOOLS
# 10757                                            Twitter  NEWS_AND_MAGAZINES
# 10721                                    Viber Messenger       COMMUNICATION
# 10578                                     Shadow Fight 2                GAME
# 10813                                      Google Photos         PHOTOGRAPHY
# 10724                        LINE: Free Calls & Messages       COMMUNICATION
# 10717                                                Pou                GAME
# 10792                      Skype - free IM & video calls       COMMUNICATION
# 10628                                         Pokémon GO                GAME
# 10388           Minion Rush: Despicable Me Official Game                GAME
# 10694                                            Yes day                GAME
# 10695                                            Hay Day              FAMILY
# 10644                           Dream League Soccer 2018                GAME
# 10696                                  My Talking Angela                GAME
# 10660             VivaVideo - Video Editor & Photo Movie       VIDEO_PLAYERS
# 10786                       Google Chrome: Fast & Secure       COMMUNICATION
# 10817                          Maps - Navigate & Explore    TRAVEL_AND_LOCAL
# 10672                                  Hill Climb Racing                GAME
# 10734                                      Facebook Lite              SOCIAL
# 10649                                Asphalt 8: Airborne                GAME
# 10699                          Mobile Legends: Bang Bang                GAME
# 10322  Battery Doctor-Battery Life Saver & Battery Co...               TOOLS
# 10396                                     Piano Tiles 2™                GAME
# 10777                                       Temple Run 2                GAME
# 10822                                             Google               TOOLS
# 10359  Truecaller: Caller ID, SMS spam blocking & Dialer       COMMUNICATION
# 10711                         SHAREit - Transfer & Share               TOOLS
# 10389   Sniper 3D Gun Shooter: Free Shooting Games - FPS                GAME
# 10676                                   Farm Heroes Saga                GAME
# 10576   PicsArt Photo Studio: Collage Maker & Pic Editor         PHOTOGRAPHY
# 10461  PhotoGrid: Video & Pic Collage Maker, Photo Ed...         PHOTOGRAPHY
# 10502   GO Launcher - 3D parallax Themes & HD Wallpapers     PERSONALIZATION
#
#        Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805    4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785    4.40  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806    4.50  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784    4.00  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650    4.60  44891723     98.00    100,000,000  Free     0   Everyone 10+
# 10744    4.70  42916526      3.40    500,000,000  Free     0       Everyone
# 10835    4.50  27722264     76.00  1,000,000,000  Free     0   Everyone 10+
# 10828    4.30  25655305      4.65  1,000,000,000  Free     0           Teen
# 10746    4.70  24900999      3.40    500,000,000  Free     0       Everyone
# 10584    4.60  23133508     97.00    100,000,000  Free     0   Everyone 10+
# 10763    4.40  22426677     74.00    500,000,000  Free     0       Everyone
# 10770    4.50  17712922     40.00    500,000,000  Free     0           Teen
# 10735    4.00  17014787      5.30    500,000,000  Free     0           Teen
# 10489    4.60  16771865      3.40    100,000,000  Free     0       Everyone
# 10731    4.50  14891223     36.00    500,000,000  Free     0       Everyone
# 10594    4.50  14198297     52.00    100,000,000  Free     0       Everyone
# 10302    4.50  13479633     14.00    100,000,000  Free     0       Everyone
# 10354    4.30  12842860      3.50    100,000,000  Free     0       Everyone
# 10549    4.50  12759663     15.00    100,000,000  Free     0       Everyone
# 10757    4.30  11667403      6.30    500,000,000  Free     0     Mature 17+
# 10721    4.30  11334799      3.50    500,000,000  Free     0       Everyone
# 10578    4.60  10979062     88.00    100,000,000  Free     0   Everyone 10+
# 10813    4.50  10858556      6.90  1,000,000,000  Free     0       Everyone
# 10724    4.20  10790289      3.50    500,000,000  Free     0       Everyone
# 10717    4.30  10485308     24.00    500,000,000  Free     0       Everyone
# 10792    4.10  10484169      3.50  1,000,000,000  Free     0       Everyone
# 10628    4.10  10424925     85.00    100,000,000  Free     0       Everyone
# 10388    4.50  10216538     36.00    100,000,000  Free     0   Everyone 10+
# 10694    4.50  10055521     94.00    100,000,000  Free     0       Everyone
# 10695    4.50  10053186     94.00    100,000,000  Free     0       Everyone
# 10644    4.60   9882639     74.00    100,000,000  Free     0       Everyone
# 10696    4.50   9881829     99.00    100,000,000  Free     0       Everyone
# 10660    4.60   9879473     40.00    100,000,000  Free     0           Teen
# 10786    4.30   9642995      3.50  1,000,000,000  Free     0       Everyone
# 10817    4.30   9235155     12.00  1,000,000,000  Free     0       Everyone
# 10672    4.40   8923587     63.00    100,000,000  Free     0       Everyone
# 10734    4.30   8606259      5.30    500,000,000  Free     0           Teen
# 10649    4.50   8389714     92.00    100,000,000  Free     0           Teen
# 10699    4.40   8219586     99.00    100,000,000  Free     0           Teen
# 10322    4.50   8190074     17.00    100,000,000  Free     0       Everyone
# 10396    4.70   8118880     36.00    100,000,000  Free     0       Everyone
# 10777    4.30   8118609     62.00    500,000,000  Free     0       Everyone
# 10822    4.40   8033493      3.40  1,000,000,000  Free     0       Everyone
# 10359    4.50   7820209      3.50    100,000,000  Free     0       Everyone
# 10711    4.60   7790693     17.00    500,000,000  Free     0       Everyone
# 10389    4.60   7671249     36.00    100,000,000  Free     0     Mature 17+
# 10676    4.40   7614130     70.00    100,000,000  Free     0       Everyone
# 10576    4.50   7594559     34.00    100,000,000  Free     0           Teen
# 10461    4.60   7529865      6.90    100,000,000  Free     0       Everyone
# 10502    4.50   7464996      6.15    100,000,000  Free     0       Everyone
#
#                           Genres    Last_Updated         Android_Ver
# 10805                     Social  August 3, 2018  Varies with device
# 10785              Communication  August 3, 2018  Varies with device
# 10806                     Social   July 31, 2018  Varies with device
# 10784              Communication  August 1, 2018  Varies with device
# 10650                   Strategy   July 15, 2018          4.1 and up
# 10744                      Tools  August 3, 2018  Varies with device
# 10835                     Arcade   July 12, 2018          4.1 and up
# 10828    Video Players & Editors  August 2, 2018  Varies with device
# 10746                      Tools  August 4, 2018  Varies with device
# 10584                   Strategy   June 27, 2018          4.1 and up
# 10763                     Casual    July 5, 2018          4.1 and up
# 10770              Communication  August 2, 2018          4.0 and up
# 10735                     Social   July 30, 2018  Varies with device
# 10489                      Tools  August 4, 2018  Varies with device
# 10731                     Casual   July 19, 2018          4.1 and up
# 10594                     Sports   July 31, 2018        4.0.3 and up
# 10302                      Tools    June 5, 2018          4.0 and up
# 10354              Communication  August 2, 2018        4.0.3 and up
# 10549                      Tools   July 25, 2018          4.0 and up
# 10757           News & Magazines  August 6, 2018  Varies with device
# 10721              Communication   July 18, 2018  Varies with device
# 10578                     Action    July 2, 2018          3.0 and up
# 10813                Photography  August 6, 2018  Varies with device
# 10724              Communication   July 26, 2018  Varies with device
# 10717                     Casual    May 25, 2018          4.0 and up
# 10792              Communication  August 3, 2018  Varies with device
# 10628                  Adventure   July 23, 2018          4.4 and up
# 10388  Casual;Action & Adventure   July 12, 2018  Varies with device
# 10694                     Casual   June 28, 2018        4.0.3 and up
# 10695                     Casual   June 28, 2018        4.0.3 and up
# 10644                     Sports   July 16, 2018          4.4 and up
# 10696                     Casual    July 3, 2018          4.1 and up
# 10660    Video Players & Editors  August 4, 2018          4.1 and up
# 10786              Communication  August 1, 2018  Varies with device
# 10817             Travel & Local   July 31, 2018  Varies with device
# 10672                     Racing    July 2, 2018          4.2 and up
# 10734                     Social  August 1, 2018  Varies with device
# 10649                     Racing    July 4, 2018        4.0.3 and up
# 10699                     Action   July 24, 2018        4.0.3 and up
# 10322                      Tools    June 1, 2018          4.0 and up
# 10396                     Arcade  August 3, 2018          4.1 and up
# 10777                     Action    July 5, 2018          4.0 and up
# 10822                      Tools  August 3, 2018  Varies with device
# 10359              Communication  August 1, 2018  Varies with device
# 10711                      Tools   July 30, 2018          4.1 and up
# 10389                     Action  August 2, 2018  Varies with device
# 10676                     Casual   July 26, 2018          2.3 and up
# 10576                Photography  August 6, 2018        4.0.3 and up
# 10461                Photography  August 6, 2018  Varies with device
# 10502            Personalization  August 3, 2018  Varies with device

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
# These are sorted by the size of the app
df_apps_dedup.sort_values('Size_MBs', ascending=False).head(20)
# Out:
#                                                      App            Category  \
# 10295                                    SimCity BuildIt              FAMILY
# 3144                                          Vi Trainer  HEALTH_AND_FITNESS
# 4176    Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 7926                                           Post Bank             FINANCE
# 8718                   Mini Golf King - Multiplayer Game                GAME
# 7927                         The Walking Dead: Our World                GAME
# 7928                       Stickman Legends: Shadow Wars                GAME
# 9945                                     Ultimate Tennis              SPORTS
# 9942                      Talking Babsy Baby: Baby Games           LIFESTYLE
# 9943                               Miami crime simulator                GAME
# 10687                             Hungry Shark Evolution                GAME
# 1795                                Navi Radiography Pro             MEDICAL
# 8719                          Draft Simulator for FUT 18              SPORTS
# 9944                        Gangster Town: Vice District              FAMILY
# 9962   Miraculous Ladybug & Cat Noir - The Official Game                GAME
# 9968                               Miami Crime Vice Town                GAME
# 5848                         Five Nights at Freddy's: SL                GAME
# 6416   Xtreme Racing 2018 - Jeep & 4x4 off road simul...              FAMILY
# 9965                      Arena of Valor: 5v5 Arena Game                GAME
# 9966                         Kill Shot Bravo: Sniper FPS                GAME
#
#        Rating  Reviews  Size_MBs     Installs  Type   Price Content_Rating  \
# 10295    4.50  4218587    100.00   50,000,000  Free       0   Everyone 10+
# 3144     3.60      124    100.00        5,000  Free       0       Everyone
# 4176     3.60      151    100.00       10,000  Free       0       Everyone
# 7926     4.50    60449    100.00    1,000,000  Free       0       Everyone
# 8718     4.50   531458    100.00    5,000,000  Free       0       Everyone
# 7927     4.00    22435    100.00    1,000,000  Free       0           Teen
# 7928     4.40    38419    100.00    1,000,000  Paid   $0.99   Everyone 10+
# 9945     4.30   183004    100.00   10,000,000  Free       0       Everyone
# 9942     4.00   140995    100.00   10,000,000  Free       0       Everyone
# 9943     4.00   254518    100.00   10,000,000  Free       0     Mature 17+
# 10687    4.50  6074334    100.00  100,000,000  Free       0           Teen
# 1795     4.70       11    100.00          500  Paid  $15.99       Everyone
# 8719     4.60   162933    100.00    5,000,000  Free       0       Everyone
# 9944     4.30    65146    100.00   10,000,000  Free       0     Mature 17+
# 9962     4.50   183846     99.00   10,000,000  Free       0       Everyone
# 9968     4.10   154519     99.00   10,000,000  Free       0     Mature 17+
# 5848     4.50    16162     99.00      100,000  Paid   $2.99           Teen
# 6416     4.20     2178     99.00      500,000  Free       0       Everyone
# 9965     4.40   438911     99.00   10,000,000  Free       0           Teen
# 9966     4.40   579519     99.00   10,000,000  Free       0     Mature 17+
#
#                           Genres      Last_Updated   Android_Ver
# 10295                 Simulation     June 19, 2018    4.0 and up
# 3144            Health & Fitness    August 2, 2018    5.0 and up
# 4176                      Racing      May 20, 2018    4.1 and up
# 7926                     Finance     July 23, 2018    4.0 and up
# 8718                      Sports     July 20, 2018  4.0.3 and up
# 7927                      Action    August 1, 2018    5.0 and up
# 7928                      Action    August 3, 2018    4.1 and up
# 9945                      Sports     July 19, 2018  4.0.3 and up
# 9942      Lifestyle;Pretend Play     July 16, 2018    4.0 and up
# 9943                      Action      July 9, 2018    4.0 and up
# 10687                     Arcade     July 25, 2018    4.1 and up
# 1795                     Medical  January 14, 2018  4.0.3 and up
# 8719                      Sports      May 11, 2018    4.1 and up
# 9944                  Simulation      May 31, 2018    4.0 and up
# 9962                      Action     July 30, 2018    4.4 and up
# 9968                      Action       May 9, 2017    2.3 and up
# 5848                      Action     April 6, 2017    2.3 and up
# 6416   Racing;Action & Adventure   August 23, 2017    4.1 and up
# 9965                      Action     June 28, 2018  4.0.3 and up
# 9966                      Action     July 18, 2018    4.1 and up

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
# Now let's get the first 50, and count how many are paid apps
df_apps_dedup.sort_values('Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# 10770        UC Browser - Fast Download Private & Secure       COMMUNICATION
# 10735                                           Snapchat              SOCIAL
# 10489    360 Security - Free Antivirus, Booster, Cleaner               TOOLS
# 10731                                     My Talking Tom                GAME
# 10594                                        8 Ball Pool                GAME
# 10302  DU Battery Saver - Battery Charger & Battery Life               TOOLS
# 10354                        BBM - Free Calls & Messages       COMMUNICATION
# 10549  Cache Cleaner-DU Speed Booster (booster & clea...               TOOLS
# 10757                                            Twitter  NEWS_AND_MAGAZINES
# 10721                                    Viber Messenger       COMMUNICATION
# 10578                                     Shadow Fight 2                GAME
# 10813                                      Google Photos         PHOTOGRAPHY
# 10724                        LINE: Free Calls & Messages       COMMUNICATION
# 10717                                                Pou                GAME
# 10792                      Skype - free IM & video calls       COMMUNICATION
# 10628                                         Pokémon GO                GAME
# 10388           Minion Rush: Despicable Me Official Game                GAME
# 10694                                            Yes day                GAME
# 10695                                            Hay Day              FAMILY
# 10644                           Dream League Soccer 2018                GAME
# 10696                                  My Talking Angela                GAME
# 10660             VivaVideo - Video Editor & Photo Movie       VIDEO_PLAYERS
# 10786                       Google Chrome: Fast & Secure       COMMUNICATION
# 10817                          Maps - Navigate & Explore    TRAVEL_AND_LOCAL
# 10672                                  Hill Climb Racing                GAME
# 10734                                      Facebook Lite              SOCIAL
# 10649                                Asphalt 8: Airborne                GAME
# 10699                          Mobile Legends: Bang Bang                GAME
# 10322  Battery Doctor-Battery Life Saver & Battery Co...               TOOLS
# 10396                                     Piano Tiles 2™                GAME
# 10777                                       Temple Run 2                GAME
# 10822                                             Google               TOOLS
# 10359  Truecaller: Caller ID, SMS spam blocking & Dialer       COMMUNICATION
# 10711                         SHAREit - Transfer & Share               TOOLS
# 10389   Sniper 3D Gun Shooter: Free Shooting Games - FPS                GAME
# 10676                                   Farm Heroes Saga                GAME
# 10576   PicsArt Photo Studio: Collage Maker & Pic Editor         PHOTOGRAPHY
# 10461  PhotoGrid: Video & Pic Collage Maker, Photo Ed...         PHOTOGRAPHY
# 10502   GO Launcher - 3D parallax Themes & HD Wallpapers     PERSONALIZATION
#
#        Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805    4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785    4.40  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806    4.50  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784    4.00  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650    4.60  44891723     98.00    100,000,000  Free     0   Everyone 10+
# 10744    4.70  42916526      3.40    500,000,000  Free     0       Everyone
# 10835    4.50  27722264     76.00  1,000,000,000  Free     0   Everyone 10+
# 10828    4.30  25655305      4.65  1,000,000,000  Free     0           Teen
# 10746    4.70  24900999      3.40    500,000,000  Free     0       Everyone
# 10584    4.60  23133508     97.00    100,000,000  Free     0   Everyone 10+
# 10763    4.40  22426677     74.00    500,000,000  Free     0       Everyone
# 10770    4.50  17712922     40.00    500,000,000  Free     0           Teen
# 10735    4.00  17014787      5.30    500,000,000  Free     0           Teen
# 10489    4.60  16771865      3.40    100,000,000  Free     0       Everyone
# 10731    4.50  14891223     36.00    500,000,000  Free     0       Everyone
# 10594    4.50  14198297     52.00    100,000,000  Free     0       Everyone
# 10302    4.50  13479633     14.00    100,000,000  Free     0       Everyone
# 10354    4.30  12842860      3.50    100,000,000  Free     0       Everyone
# 10549    4.50  12759663     15.00    100,000,000  Free     0       Everyone
# 10757    4.30  11667403      6.30    500,000,000  Free     0     Mature 17+
# 10721    4.30  11334799      3.50    500,000,000  Free     0       Everyone
# 10578    4.60  10979062     88.00    100,000,000  Free     0   Everyone 10+
# 10813    4.50  10858556      6.90  1,000,000,000  Free     0       Everyone
# 10724    4.20  10790289      3.50    500,000,000  Free     0       Everyone
# 10717    4.30  10485308     24.00    500,000,000  Free     0       Everyone
# 10792    4.10  10484169      3.50  1,000,000,000  Free     0       Everyone
# 10628    4.10  10424925     85.00    100,000,000  Free     0       Everyone
# 10388    4.50  10216538     36.00    100,000,000  Free     0   Everyone 10+
# 10694    4.50  10055521     94.00    100,000,000  Free     0       Everyone
# 10695    4.50  10053186     94.00    100,000,000  Free     0       Everyone
# 10644    4.60   9882639     74.00    100,000,000  Free     0       Everyone
# 10696    4.50   9881829     99.00    100,000,000  Free     0       Everyone
# 10660    4.60   9879473     40.00    100,000,000  Free     0           Teen
# 10786    4.30   9642995      3.50  1,000,000,000  Free     0       Everyone
# 10817    4.30   9235155     12.00  1,000,000,000  Free     0       Everyone
# 10672    4.40   8923587     63.00    100,000,000  Free     0       Everyone
# 10734    4.30   8606259      5.30    500,000,000  Free     0           Teen
# 10649    4.50   8389714     92.00    100,000,000  Free     0           Teen
# 10699    4.40   8219586     99.00    100,000,000  Free     0           Teen
# 10322    4.50   8190074     17.00    100,000,000  Free     0       Everyone
# 10396    4.70   8118880     36.00    100,000,000  Free     0       Everyone
# 10777    4.30   8118609     62.00    500,000,000  Free     0       Everyone
# 10822    4.40   8033493      3.40  1,000,000,000  Free     0       Everyone
# 10359    4.50   7820209      3.50    100,000,000  Free     0       Everyone
# 10711    4.60   7790693     17.00    500,000,000  Free     0       Everyone
# 10389    4.60   7671249     36.00    100,000,000  Free     0     Mature 17+
# 10676    4.40   7614130     70.00    100,000,000  Free     0       Everyone
# 10576    4.50   7594559     34.00    100,000,000  Free     0           Teen
# 10461    4.60   7529865      6.90    100,000,000  Free     0       Everyone
# 10502    4.50   7464996      6.15    100,000,000  Free     0       Everyone
#
#                           Genres    Last_Updated         Android_Ver
# 10805                     Social  August 3, 2018  Varies with device
# 10785              Communication  August 3, 2018  Varies with device
# 10806                     Social   July 31, 2018  Varies with device
# 10784              Communication  August 1, 2018  Varies with device
# 10650                   Strategy   July 15, 2018          4.1 and up
# 10744                      Tools  August 3, 2018  Varies with device
# 10835                     Arcade   July 12, 2018          4.1 and up
# 10828    Video Players & Editors  August 2, 2018  Varies with device
# 10746                      Tools  August 4, 2018  Varies with device
# 10584                   Strategy   June 27, 2018          4.1 and up
# 10763                     Casual    July 5, 2018          4.1 and up
# 10770              Communication  August 2, 2018          4.0 and up
# 10735                     Social   July 30, 2018  Varies with device
# 10489                      Tools  August 4, 2018  Varies with device
# 10731                     Casual   July 19, 2018          4.1 and up
# 10594                     Sports   July 31, 2018        4.0.3 and up
# 10302                      Tools    June 5, 2018          4.0 and up
# 10354              Communication  August 2, 2018        4.0.3 and up
# 10549                      Tools   July 25, 2018          4.0 and up
# 10757           News & Magazines  August 6, 2018  Varies with device
# 10721              Communication   July 18, 2018  Varies with device
# 10578                     Action    July 2, 2018          3.0 and up
# 10813                Photography  August 6, 2018  Varies with device
# 10724              Communication   July 26, 2018  Varies with device
# 10717                     Casual    May 25, 2018          4.0 and up
# 10792              Communication  August 3, 2018  Varies with device
# 10628                  Adventure   July 23, 2018          4.4 and up
# 10388  Casual;Action & Adventure   July 12, 2018  Varies with device
# 10694                     Casual   June 28, 2018        4.0.3 and up
# 10695                     Casual   June 28, 2018        4.0.3 and up
# 10644                     Sports   July 16, 2018          4.4 and up
# 10696                     Casual    July 3, 2018          4.1 and up
# 10660    Video Players & Editors  August 4, 2018          4.1 and up
# 10786              Communication  August 1, 2018  Varies with device
# 10817             Travel & Local   July 31, 2018  Varies with device
# 10672                     Racing    July 2, 2018          4.2 and up
# 10734                     Social  August 1, 2018  Varies with device
# 10649                     Racing    July 4, 2018        4.0.3 and up
# 10699                     Action   July 24, 2018        4.0.3 and up
# 10322                      Tools    June 1, 2018          4.0 and up
# 10396                     Arcade  August 3, 2018          4.1 and up
# 10777                     Action    July 5, 2018          4.0 and up
# 10822                      Tools  August 3, 2018  Varies with device
# 10359              Communication  August 1, 2018  Varies with device
# 10711                      Tools   July 30, 2018          4.1 and up
# 10389                     Action  August 2, 2018  Varies with device
# 10676                     Casual   July 26, 2018          2.3 and up
# 10576                Photography  August 6, 2018        4.0.3 and up
# 10461                Photography  August 6, 2018  Varies with device
# 10502            Personalization  August 3, 2018  Varies with device

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_dedup.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6619
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
ratings.describe()
# Out:
# count       6.00
# mean    1,366.17
# std     2,594.80
# min         1.00
# 25%        78.50
# 50%       331.00
# 75%       773.25
# max     6,619.00
# Name: count, dtype: float64

# %%
ratings.head()
# Out:
# Content_Rating
# Everyone           6619
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="9787c502-3319-4f60-bd03-217dfaa2463b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9787c502-3319-4f60-bd03-217dfaa2463b")) {                    Plotly.newPlot(                        "9787c502-3319-4f60-bd03-217dfaa2463b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6619,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatte ...

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
hole=0.4)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="6bb855af-795e-47bd-9944-b40760550a4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bb855af-795e-47bd-9944-b40760550a4a")) {                    Plotly.newPlot(                        "6bb855af-795e-47bd-9944-b40760550a4a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6619,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"ty ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_dedup.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres      Last_Updated  \
# 21     25.00        1  Free      0       Everyone  Medical    August 2, 2018
# 28     20.00        1  Paid  $1.49       Everyone   Arcade  February 8, 2017
# 47     16.00        1  Paid  $0.99       Everyone   Arcade     March 3, 2017
# 82     19.00        5  Free      0       Everyone   Arcade     July 23, 2018
# 99      4.60        5  Free      0       Everyone  Medical    August 2, 2018
#
#      Android_Ver
# 21  4.0.3 and up
# 28    2.3 and up
# 47    2.3 and up
# 82    4.1 and up
# 99    4.0 and up

# %%
df_apps_dedup.sort_values(by=['Installs'], ascending=False).tail(10)
# Out:
#                                   App         Category  Rating  Reviews  \
# 2408   BP Tracker-Symptoms & Solution          MEDICAL    4.20       34
# 2407                       Dy So Exam           FAMILY    3.00        6
# 2406                    CI Dictionary           FAMILY    4.60       31
# 2405  ALPHA - Artificial Intelligence           FAMILY    4.00       51
# 2404                BK Shivani Videos        LIFESTYLE    4.70       29
# 2403           CI Screwed - Icon Pack  PERSONALIZATION    4.70       19
# 2402                          EG Movi            TOOLS    4.20       40
# 28                           Ra Ga Ba             GAME    5.00        2
# 47                            Mu.F.O.             GAME    5.00        2
# 21                KBA-EZ Health Guide          MEDICAL    5.00        4
#
#       Size_MBs Installs  Type  Price Content_Rating           Genres  \
# 2408      3.20    1,000  Free      0       Everyone          Medical
# 2407      3.20    1,000  Free      0       Everyone        Education
# 2406      3.20    1,000  Free      0       Everyone        Education
# 2405      3.20    1,000  Free      0       Everyone    Entertainment
# 2404      3.20    1,000  Free      0       Everyone        Lifestyle
# 2403      6.40    1,000  Free      0       Everyone  Personalization
# 2402      7.40    1,000  Free      0       Everyone            Tools
# 28       20.00        1  Paid  $1.49       Everyone           Arcade
# 47       16.00        1  Paid  $0.99       Everyone           Arcade
# 21       25.00        1  Free      0       Everyone          Medical
#
#            Last_Updated   Android_Ver
# 2408   October 12, 2016    3.0 and up
# 2407       July 3, 2017    2.3 and up
# 2406  September 1, 2015  4.0.3 and up
# 2405       June 3, 2018    4.0 and up
# 2404      July 25, 2018  4.0.3 and up
# 2403      June 30, 2016  4.0.3 and up
# 2402       May 12, 2017    3.2 and up
# 28     February 8, 2017    2.3 and up
# 47        March 3, 2017    2.3 and up
# 21       August 2, 2018  4.0.3 and up

# %%
# These are the counts for each level of installation.  The values are sorted, but we can see they are sorted by an alpha-influenced order.
df_apps_dedup.groupby('Installs')['Installs'].count()
# Out:
# Installs
# 1                   3
# 1,000             697
# 1,000,000        1417
# 1,000,000,000      20
# 10                 69
# 10,000            987
# 10,000,000        933
# 100               303
# 100,000          1096
# 100,000,000       189
# 5                   9
# 5,000             425
# 5,000,000         607
# 50                 56
# 50,000            457
# 50,000,000        202
# 500               199
# 500,000           504
# 500,000,000        24
# Name: Installs, dtype: int64

# %%
# We can see the Installs are of type object, which we have to convert to a number. The present value of the object has commas.
df_apps_dedup.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size_MBs          float64
# Installs           object
# Type               object
# Price              object
# Content_Rating     object
# Genres             object
# Last_Updated       object
# Android_Ver        object
# dtype: object

# %%
# convert the column from type object to an int64 for the dataframe df_apps_dedup
import pandas as pd
df_apps_numbers = df_apps_dedup.copy()
df_apps_numbers.Installs = [x.replace(',','') for x in df_apps_numbers.Installs]
df_apps_numbers.Installs = pd.to_numeric(df_apps_numbers.Installs)
df_apps_numbers.groupby('Installs')['Installs'].count()
# Out:
# Installs
# 1                3
# 5                9
# 10              69
# 50              56
# 100            303
# 500            199
# 1000           697
# 5000           425
# 10000          987
# 50000          457
# 100000        1096
# 500000         504
# 1000000       1417
# 5000000        607
# 10000000       933
# 50000000       202
# 100000000      189
# 500000000       24
# 1000000000      20
# Name: Installs, dtype: int64

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
# Find the most expensive apps.  Let's see what we have first
df_apps_clean.sort_values('Price', ascending=True).head()
# We can see the data has dollar signs, which clobber the format.
# Out:
#                                  App         Category  Rating  Reviews  \
# 1472                        FO Bixby  PERSONALIZATION    5.00        5
# 4975       ZOOKEEPER DX TouchEdition           FAMILY    4.20     3195
# 748          Interactive NPC DM Tool           FAMILY    2.80        5
# 1203  World Racers family board game           FAMILY    4.80        4
# 1204           Dress Up RagazzA13 DX           FAMILY    3.50       13
#
#       Size_MBs Installs  Type  Price Content_Rating              Genres  \
# 1472      0.84      100  Paid  $0.99       Everyone     Personalization
# 4975      4.60  100,000  Paid  $0.99       Everyone              Puzzle
# 748       0.61       50  Paid  $0.99       Everyone        Role Playing
# 1203     42.00      100  Paid  $0.99       Everyone  Board;Pretend Play
# 1204     42.00      100  Paid  $0.99       Everyone          Simulation
#
#             Last_Updated   Android_Ver
# 1472      April 25, 2018    7.0 and up
# 4975   November 26, 2015    2.1 and up
# 748     January 31, 2015  2.3.3 and up
# 1203   September 3, 2015    5.1 and up
# 1204  September 16, 2016  4.0.3 and up

# %%
# let's count the number with a groupby.  The results show we have 73 items in this list.
df_apps_clean.groupby('Price').Price.count()
# Out:
# Price
# $0.99     107
# $1.00       2
# $1.20       1
# $1.29       1
# $1.49      30
#          ...
# $8.49       1
# $8.99       4
# $9.00       2
# $9.99      16
# 0        8719
# Name: Price, Length: 73, dtype: int64

# %%
# Now let's strip out the dollar signs.
df_apps_cleaner = df_apps_clean.copy()
df_apps_cleaner.Price = [x.replace('$', '') for x in df_apps_cleaner.Price]
df_apps_cleaner.Price = pd.to_numeric(df_apps_cleaner.Price)
df_apps_cleaner.groupby('Price')['Price'].count()
# Out:
# Price
# 0.00      8719
# 0.99       107
# 1.00         2
# 1.20         1
# 1.29         1
#           ...
# 299.99       1
# 379.99       1
# 389.99       1
# 399.99      11
# 400.00       1
# Name: Price, Length: 73, dtype: int64

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# In this example, we filter out the apps that cost 250 or more
df_apps_cleaner[df_apps_cleaner.Price >= 250]
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# 3897                       I Am Rich     FAMILY    3.60      217      4.90
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
#
#      Installs  Type  Price Content_Rating         Genres       Last_Updated  \
# 1331      100  Paid 399.99       Everyone  Entertainment      July 16, 2018
# 1946    1,000  Paid 399.99           Teen        Finance   December 6, 2017
# 2193    1,000  Paid 379.99       Everyone      Lifestyle       July 1, 2018
# 2394    1,000  Paid 399.99       Everyone        Finance  December 11, 2017
# 2461    1,000  Paid 399.99       Everyone        Finance      June 25, 2018
# 2775    5,000  Paid 399.99       Everyone  Entertainment       May 30, 2017
# 3114    5,000  Paid 399.99       Everyone        Finance     March 22, 2018
# 3145    5,000  Paid 399.99       Everyone        Finance        May 1, 2017
# 3221   10,000  Paid 399.99       Everyone  Entertainment       May 19, 2018
# 3554   10,000  Paid 399.99       Everyone      Lifestyle     March 11, 2018
# 3856   10,000  Paid 299.99       Everyone      Lifestyle      July 21, 2018
# 3897   10,000  Paid 389.99       Everyone  Entertainment      June 22, 2018
# 3946   10,000  Paid 400.00       Everyone      Lifestyle        May 3, 2018
# 4606   50,000  Paid 399.99       Everyone        Finance  November 12, 2017
# 5765  100,000  Paid 399.99       Everyone      Lifestyle   January 12, 2018
#
#        Android_Ver
# 1331    7.0 and up
# 1946  4.0.3 and up
# 2193    4.0 and up
# 2394    4.1 and up
# 2461    4.1 and up
# 2775    1.6 and up
# 3114    4.2 and up
# 3145    4.4 and up
# 3221    4.4 and up
# 3554    4.4 and up
# 3856    4.3 and up
# 3897    4.2 and up
# 3946    4.1 and up
# 4606    4.0 and up
# 5765  4.0.3 and up

# %%
# In this example, we filter out the apps that cost 250 or more
df_apps_cleaner[df_apps_cleaner.Price >= 250].count()
# Out:
# App               15
# Category          15
# Rating            15
# Reviews           15
# Size_MBs          15
# Installs          15
# Type              15
# Price             15
# Content_Rating    15
# Genres            15
# Last_Updated      15
# Android_Ver       15
# dtype: int64

# %%
df_apps_cleaner[df_apps_cleaner.Price <= 250].sort_values(by="Price", ascending=False).head(10)
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2282  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2482    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 2481    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 2207                   EMT PASS    MEDICAL    3.40       51      2.40
# 2464         PTA Content Master    MEDICAL    4.20       64     41.00
# 504   AP Art History Flashcards     FAMILY    5.00        1     96.00
# 2208                   EMT PASS    MEDICAL    3.40       51      2.40
#
#      Installs  Type  Price Content_Rating     Genres       Last_Updated  \
# 2282    1,000  Paid  79.99       Everyone    Medical      June 18, 2018
# 2281    1,000  Paid  79.99       Everyone    Medical      June 18, 2018
# 1407      100  Paid  39.99       Everyone    Medical      April 4, 2018
# 2629    1,000  Paid  37.99       Everyone  Lifestyle      July 18, 2017
# 2482    1,000  Paid  33.99       Everyone    Medical    October 2, 2017
# 2481    1,000  Paid  33.99       Everyone    Medical    October 2, 2017
# 2207    1,000  Paid  29.99       Everyone    Medical   October 22, 2014
# 2464    1,000  Paid  29.99       Everyone    Medical  December 22, 2015
# 504        10  Paid  29.99     Mature 17+  Education   January 19, 2016
# 2208    1,000  Paid  29.99       Everyone    Medical   October 22, 2014
#
#        Android_Ver
# 2282  4.0.3 and up
# 2281  4.0.3 and up
# 1407    4.1 and up
# 2629  4.0.3 and up
# 2482    4.0 and up
# 2481    4.0 and up
# 2207    4.0 and up
# 2464    2.2 and up
# 504     4.0 and up
# 2208    4.0 and up

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_cleaner.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size_MBs          float64
# Installs           object
# Type               object
# Price             float64
# Content_Rating     object
# Genres             object
# Last_Updated       object
# Android_Ver        object
# dtype: object

# %%
# Find out if any of the price entries are blank
df_apps_cleaner.Price.isna().any()
# Out:
# np.False_

# %%
# Is any price blank?
df_apps_cleaner.Price.isnull().values.any()
# Out:
# np.False_

# %%
# is any install blank?
df_apps_cleaner.Installs.isna().any()
# Out:
# np.False_

# %%
# is any install blank?
df_apps_cleaner.Installs.isnull().values.any()
# Out:
# np.False_

# %%
# Installs are of type object.  We need to convert them to integers
#df_apps_cleaner.Installs = pd.to_numeric(df_apps_cleaner.Installs)
df_apps_cleaner.dtypes
# Out:
# Revenue_Estimate    float64
# App                  object
# Category             object
# Rating              float64
# Reviews               int64
# Size_MBs            float64
# Installs              int64
# Type                 object
# Price               float64
# Content_Rating       object
# Genres               object
# Last_Updated         object
# Android_Ver          object
# dtype: object

# %%
# Here, we have to do a couple of clever things.
# The first is we multiple the price by the number of installs. We'll pretend this is a proxy for revenue.
# We store this product as a new value, which we'll call Revenue_Estimate
# Then we sort the new list and present the head() of the results

df_apps_cleaner.Installs = [x.replace(',','') for x in df_apps_cleaner.Installs]
df_apps_cleaner.Installs = pd.to_numeric(df_apps_cleaner.Installs)
df_apps_cleaner.insert(0, "Revenue_Estimate", df_apps_cleaner.Price * df_apps_cleaner.Installs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 6
#       1 # Here, we have to do a couple of clever things.
#       2 # The first is we multiple the price by the number of installs. We'll pretend this is a proxy for revenue.
#       3 # We store this product as a new value, which we'll call Revenue_Estimate
#       4 # Then we sort the new list and present the head() of the results
# ----> 6 df_apps_cleaner.Installs = [x.replace(',','') for x in df_apps_cleaner.Installs]
#       7 df_apps_cleaner.Installs = pd.to_numeric(df_apps_cleaner.Installs)
#       9 df_apps_cleaner.insert(0, "Revenue_Estimate", df_apps_cleaner.Price * df_apps_cleaner.Installs)
#
# Cell In[92], line 6, in <listcomp>(.0)
#       1 # Here, we have to do a couple of clever things.
#       2 # The first is we multiple the price by the number of installs. We'll pretend this is a proxy for revenue.
#       3 # We store this product as a new value, which we'll call Revenue_Estimate
#       4 # Then we sort the new list and present the head() of the results
# ----> 6 df_apps_cleaner.Installs = [x.replace(',','') for x in df_apps_cleaner.Installs]
#       7 df_apps_cleaner.Installs = pd.to_numeric(df_apps_cleaner.Installs)
#       9 df_apps_cleaner.insert(0, "Revenue_Estimate", df_apps_cleaner.Price * df_apps_cleaner.Installs)
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
df_apps_cleaner.head()
# Out:
#     Revenue_Estimate                                              App  \
# 21              0.00                              KBA-EZ Health Guide
# 28              1.49                                         Ra Ga Ba
# 47              0.99                                          Mu.F.O.
# 82              0.00                                 Brick Breaker BR
# 99              0.00  Anatomy & Physiology Vocabulary Exam Review App
#
#    Category  Rating  Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 21  MEDICAL    5.00        4     25.00         1  Free   0.00       Everyone
# 28     GAME    5.00        2     20.00         1  Paid   1.49       Everyone
# 47     GAME    5.00        2     16.00         1  Paid   0.99       Everyone
# 82     GAME    5.00        7     19.00         5  Free   0.00       Everyone
# 99  MEDICAL    5.00        1      4.60         5  Free   0.00       Everyone
#
#      Genres      Last_Updated   Android_Ver
# 21  Medical    August 2, 2018  4.0.3 and up
# 28   Arcade  February 8, 2017    2.3 and up
# 47   Arcade     March 3, 2017    2.3 and up
# 82   Arcade     July 23, 2018    4.1 and up
# 99  Medical    August 2, 2018    4.0 and up

# %%
df_apps_cleaner.sort_values(by='Revenue_Estimate', ascending=False).head(10)
# Out:
#       Revenue_Estimate                            App     Category  Rating  \
# 9220     69,900,000.00                      Minecraft       FAMILY    4.50
# 9224     69,900,000.00                      Minecraft       FAMILY    4.50
# 5765     39,999,000.00                      I am rich    LIFESTYLE    3.80
# 4606     19,999,500.00              I Am Rich Premium      FINANCE    4.10
# 8825      9,900,000.00                  Hitman Sniper         GAME    4.60
# 7151      6,990,000.00  Grand Theft Auto: San Andreas         GAME    4.40
# 7479      5,990,000.00            Facetune - For Free  PHOTOGRAPHY    4.40
# 7478      5,990,000.00            Facetune - For Free  PHOTOGRAPHY    4.40
# 7477      5,990,000.00            Facetune - For Free  PHOTOGRAPHY    4.40
# 7977      5,990,000.00        Sleep as Android Unlock    LIFESTYLE    4.50
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 9220  2376564     19.00  10000000  Paid   6.99   Everyone 10+
# 9224  2375336     19.00  10000000  Paid   6.99   Everyone 10+
# 5765     3547      1.80    100000  Paid 399.99       Everyone
# 4606     1867      4.70     50000  Paid 399.99       Everyone
# 8825   408292     29.00  10000000  Paid   0.99     Mature 17+
# 7151   348962     26.00   1000000  Paid   6.99     Mature 17+
# 7479    49553     48.00   1000000  Paid   5.99       Everyone
# 7478    49553     48.00   1000000  Paid   5.99       Everyone
# 7477    49553     48.00   1000000  Paid   5.99       Everyone
# 7977    23966      0.85   1000000  Paid   5.99       Everyone
#
#                          Genres       Last_Updated         Android_Ver
# 9220  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 9224  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 5765                  Lifestyle   January 12, 2018        4.0.3 and up
# 4606                    Finance  November 12, 2017          4.0 and up
# 8825                     Action      July 12, 2018          4.1 and up
# 7151                     Action     March 21, 2015          3.0 and up
# 7479                Photography      July 25, 2018          4.1 and up
# 7478                Photography      July 25, 2018          4.1 and up
# 7477                Photography      July 25, 2018          4.1 and up
# 7977                  Lifestyle      June 27, 2018          4.0 and up

# %%
df_apps_cleaner[df_apps_cleaner.Price <= 250].sort_values(by="Revenue_Estimate", ascending=False).head(10)
# Out:
#       Revenue_Estimate                            App     Category  Rating  \
# 9220     69,900,000.00                      Minecraft       FAMILY    4.50
# 9224     69,900,000.00                      Minecraft       FAMILY    4.50
# 8825      9,900,000.00                  Hitman Sniper         GAME    4.60
# 7151      6,990,000.00  Grand Theft Auto: San Andreas         GAME    4.40
# 7478      5,990,000.00            Facetune - For Free  PHOTOGRAPHY    4.40
# 7977      5,990,000.00        Sleep as Android Unlock    LIFESTYLE    4.50
# 7479      5,990,000.00            Facetune - For Free  PHOTOGRAPHY    4.40
# 7477      5,990,000.00            Facetune - For Free  PHOTOGRAPHY    4.40
# 6594      4,990,000.00            DraStic DS Emulator         GAME    4.60
# 6082      2,995,000.00                   Weather Live      WEATHER    4.50
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 9220  2376564     19.00  10000000  Paid   6.99   Everyone 10+
# 9224  2375336     19.00  10000000  Paid   6.99   Everyone 10+
# 8825   408292     29.00  10000000  Paid   0.99     Mature 17+
# 7151   348962     26.00   1000000  Paid   6.99     Mature 17+
# 7478    49553     48.00   1000000  Paid   5.99       Everyone
# 7977    23966      0.85   1000000  Paid   5.99       Everyone
# 7479    49553     48.00   1000000  Paid   5.99       Everyone
# 7477    49553     48.00   1000000  Paid   5.99       Everyone
# 6594    87766     12.00   1000000  Paid   4.99       Everyone
# 6082    76593      4.75    500000  Paid   5.99       Everyone
#
#                          Genres       Last_Updated         Android_Ver
# 9220  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 9224  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 8825                     Action      July 12, 2018          4.1 and up
# 7151                     Action     March 21, 2015          3.0 and up
# 7478                Photography      July 25, 2018          4.1 and up
# 7977                  Lifestyle      June 27, 2018          4.0 and up
# 7479                Photography      July 25, 2018          4.1 and up
# 7477                Photography      July 25, 2018          4.1 and up
# 6594                     Action      July 19, 2016          2.3 and up
# 6082                    Weather  November 21, 2017  Varies with device

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_cleaner.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_cleaner.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY           1747
# GAME             1097
# TOOLS             734
# PRODUCTIVITY      351
# MEDICAL           350
# COMMUNICATION     328
# FINANCE           323
# SPORTS            319
# PHOTOGRAPHY       317
# LIFESTYLE         315
# Name: count, dtype: int64

# %%
bar = px.bar(x = top10_category.index,
             y = top10_category.values,
             color = top10_category.index,
             title = 'Top 10 Categories by Sales')
bar.show()
# Out:
# <div>                            <div id="9afda4b1-cdba-41b1-9da9-894616769bd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9afda4b1-cdba-41b1-9da9-894616769bd5")) {                    Plotly.newPlot(                        "9afda4b1-cdba-41b1-9da9-894616769bd5",                        [{"alignmentgroup":"True","hovertemplate":"color=FAMILY\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FAMILY","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"FAMILY","offsetgroup":"FAMILY","orientation":"v","showlegend":true,"textposition":"auto","x":["FAMILY"],"xaxis":"x","y":[1747],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=GAME\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GAME","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"GAME","offsetgroup":"GAME","orientation":"v","showlegend":true,"textposition":"auto","x":["GAME"],"xaxis":"x","y":[1097],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=TOOLS\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TOOLS","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"TOOLS","offsetgroup":"TOOLS","orientation":"v","showlegend":true,"textposition":"auto","x":["TOOLS"],"xaxis":"x","y":[734],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=PRODUCTIVITY\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PRODUCTIVITY","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"PRODUCTIVITY","offsetgroup":"PRODUCTIVITY","orientation":"v","showlegend":true,"textposition":"auto","x":["PRODUCTIVITY"],"xaxis":"x","y":[351],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=MEDICAL\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MEDICAL","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"MEDICAL","offsetgroup":"MEDICAL","orientation":"v","showlegend":true,"textposition":"auto","x":["MEDICAL"],"xaxis":"x","y":[350],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=COMMUNICATION\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"COMMUNICATION","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"COMMUNICATION","offsetgroup":"COMMUNICATION","orientation":"v","showlegend":true,"textposition":"auto","x":["COMMUNICATION"],"xaxis":"x","y":[328],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=FINANCE\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FINANCE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"FINANCE","offsetgroup":"FINANCE","orientation":"v","showlegend":true,"textposition":"auto","x":["FINANCE"],"xaxis":"x","y":[323],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=SPORTS\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SPORTS","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"SPORTS","offsetgroup":"SPORTS","orientation":"v","showlegend":true,"textposition":"auto","x":["SPORTS"],"xaxis":"x","y":[319],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=PHOTOGRAPHY\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PHOTOGRAPHY","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"PHOTOGRAPHY","offsetgroup":"PHOTOGRAPHY","orientation":"v","showlegend":true,"textposition":"auto","x":["PHOTOGRAPHY"],"xaxis":"x","y":[317],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"c ...

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_cleaner.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values(by='Installs', ascending=False, inplace=True)

h_bar = px.bar(x=category_installs.Installs, 
               y=category_installs.index,
               orientation='h',
               title='Category Popularity'
               )
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')

h_bar.show()
# Out:
# <div>                            <div id="7a068e8f-7b82-4332-8bca-7d1593c2b1bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a068e8f-7b82-4332-8bca-7d1593c2b1bb")) {                    Plotly.newPlot(                        "7a068e8f-7b82-4332-8bca-7d1593c2b1bb",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[35085862717,32647241530,14176070180,14069841475,11450724500,10257701590,10088243130,7496210650,6868859300,6221897200,3247831540,2869160000,2325341930,1921291655,1751131465,1583056220,1001768120,876612400,871352000,724267560,537562120,426096500,273777750,264295110,168582000,124233100,62083000,56036100,53205576,53129800,31116110,26916200,15949410],"xaxis":"x","y":["GAME","COMMUNICATION","PRODUCTIVITY","SOCIAL","TOOLS","FAMILY","PHOTOGRAPHY","NEWS_AND_MAGAZINES","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","SHOPPING","ENTERTAINMENT","PERSONALIZATION","BOOKS_AND_REFERENCE","SPORTS","HEALTH_AND_FITNESS","BUSINESS","FINANCE","EDUCATION","MAPS_AND_NAVIGATION","LIFESTYLE","WEATHER","FOOD_AND_DRINK","DATING","HOUSE_AND_HOME","ART_AND_DESIGN","LIBRARIES_AND_DEMO","COMICS","MEDICAL","AUTO_AND_VEHICLES","PARENTING","BEAUTY","EVENTS"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
#category_installs = df_apps_cleaner.groupby('Category').agg({'Installs': pd.Series.sum})
category_number = df_apps_cleaner.groupby('Category').agg({'App': pd.Series.count})
category_merged_df = pd.merge(category_installs, category_number, on='Category')
category_merged_df.shape
# Out:
# (33, 2)

# %%
scatter = px.scatter(category_merged_df,
                     x='App',
                     y='Installs',
                     title='Category concentration',
                     size='App',
                     hover_name=category_merged_df.index,
                     color='Installs'
                     )
scatter.update_layout(xaxis_title='Number of apps',
                      yaxis_title="Installs",
                      yaxis=dict(type='log')
                      )
scatter.show()
# Out:
# <div>                            <div id="059b1e2f-5453-4be4-a8fe-bb5f69f7671d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("059b1e2f-5453-4be4-a8fe-bb5f69f7671d")) {                    Plotly.newPlot(                        "059b1e2f-5453-4be4-a8fe-bb5f69f7671d",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eApp=%{marker.size}\u003cbr\u003eInstalls=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"legendgroup":"","marker":{"color":[124233100,53129800,26916200,1921291655,1001768120,56036100,32647241530,264295110,871352000,2869160000,15949410,10257701590,876612400,273777750,35085862717,1583056220,168582000,62083000,537562120,724267560,53205576,7496210650,31116110,2325341930,10088243130,14176070180,3247831540,14069841475,1751131465,11450724500,6868859300,6221897200,426096500],"coloraxis":"coloraxis","size":[62,73,42,178,303,58,328,195,155,149,45,1747,323,109,1097,297,76,65,315,124,350,233,50,312,317,351,238,259,319,734,226,160,75],"sizemode":"area","sizeref":4.3675,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[62,73,42,178,303,58,328,195,155,149,45,1747,323,109,1097,297,76,65,315,124,350,233,50,312,317,351,238,259,319,734,226,160,75],"xaxis":"x","y":[124233100,53129800,26916200,1921291655,1001768120,56036100,32647241530,264295110,871352000,2869160000,15949410,10257701590,876612400,273777750,35085862717,1583056220,168582000,62083000,537562120,724267560,53205576,7496210650,31116110,2325341930,10088243130,14176070180,3247831540,14069841475,1751131465,11450724500,6868859300,6221897200,426096500],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]] ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_cleaner.groupby("Genres").Genres.count()
#df_apps_clean.groupby('Price').Price.count()
# Out:
# Genres
# Action                                   358
# Action;Action & Adventure                 17
# Adventure                                 73
# Adventure;Action & Adventure              13
# Adventure;Brain Games                      1
#                                         ...
# Video Players & Editors                  158
# Video Players & Editors;Creativity         2
# Video Players & Editors;Music & Video      3
# Weather                                   75
# Word                                      28
# Name: Genres, Length: 115, dtype: int64

# %%
df_apps_cleaner.groupby("Genres").Genres.value_counts()
# Notice the output contains stings like this: "Action" and "Action;Action & Adventure".  The semi-colon is the delimiter
# Out:
# Genres
# Action                                   358
# Action;Action & Adventure                 17
# Adventure                                 73
# Adventure;Action & Adventure              13
# Adventure;Brain Games                      1
#                                         ...
# Video Players & Editors                  158
# Video Players & Editors;Creativity         2
# Video Players & Editors;Music & Video      3
# Weather                                   75
# Word                                      28
# Name: count, Length: 115, dtype: int64

# %%
len(df_apps_cleaner.Genres.unique())
# Out:
# 115

# %%
# Split the column by the semicolon

stack = df_apps_cleaner.Genres.str.split(';', expand=True).stack()
print (f'The stack shape is: {stack.shape}')

num_genres = stack.value_counts()
print (f'Number of unique genres: {len(num_genres)}')
# Out:
# The stack shape is: (9848,)
# Number of unique genres: 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
genre_category = df_apps_cleaner.Genres.value_counts()[:20]
genre_category

bar = px.bar(x = genre_category.index,
             y = genre_category.values,
             title = 'Top Genres',
             hover_name=genre_category.index[:20],
             color = genre_category.values[:20],
             color_continuous_scale='Agsunset',
             )

bar.update_layout(xaxis_title='Genre',
                  yaxis_title="Number of Apps",
                  coloraxis_showscale=False,
                  )

bar.show()
# Out:
# <div>                            <div id="ceccb083-7cc2-4682-83fa-ca2ccbfb5a1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ceccb083-7cc2-4682-83fa-ca2ccbfb5a1b")) {                    Plotly.newPlot(                        "ceccb083-7cc2-4682-83fa-ca2ccbfb5a1b",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tools","Entertainment","Education","Action","Productivity","Medical","Sports","Communication","Finance","Photography","Lifestyle","Personalization","Business","Health & Fitness","Social","Shopping","News & Magazines","Travel & Local","Arcade","Dating"],"legendgroup":"","marker":{"color":[733,533,468,358,351,350,333,328,323,317,314,312,303,297,259,238,233,225,207,195],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tools","Entertainment","Education","Action","Productivity","Medical","Sports","Communication","Finance","Photography","Lifestyle","Personalization","Business","Health & Fitness","Social","Shopping","News & Magazines","Travel & Local","Arcade","Dating"],"xaxis":"x","y":[733,533,468,358,351,350,333,328,323,317,314,312,303,297,259,238,233,225,207,195],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_cleaner.Type.value_counts()
# Out:
# Type
# Free    8719
# Paid     646
# Name: count, dtype: int64

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_free_vs_paid = df_apps_cleaner.groupby(['Category', 'Type'], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.sort_values(['App'], ascending=True)
# Out:
#               Category  Type   App
# 3    AUTO_AND_VEHICLES  Paid     1
# 17       ENTERTAINMENT  Paid     2
# 24      FOOD_AND_DRINK  Paid     2
# 38  NEWS_AND_MAGAZINES  Paid     2
# 48            SHOPPING  Paid     2
# ..                 ...   ...   ...
# 21             FINANCE  Free   310
# 45        PRODUCTIVITY  Free   333
# 53               TOOLS  Free   671
# 25                GAME  Free  1020
# 19              FAMILY  Free  1585
#
# [61 rows x 3 columns]

# %%
df_free_vs_paid.sort_values(['App'], ascending=False)
# Out:
#              Category  Type   App
# 19             FAMILY  Free  1585
# 25               GAME  Free  1020
# 53              TOOLS  Free   671
# 45       PRODUCTIVITY  Free   333
# 21            FINANCE  Free   310
# ..                ...   ...   ...
# 24     FOOD_AND_DRINK  Paid     2
# 50             SOCIAL  Paid     2
# 40          PARENTING  Paid     2
# 48           SHOPPING  Paid     2
# 3   AUTO_AND_VEHICLES  Paid     1
#
# [61 rows x 3 columns]

# %%
g_bar = px.bar(df_free_vs_paid,
               x ='Category',
               y = 'App',
               title = 'Free v Paid Apps by Category',
               color ='Type',
               barmode = 'group'
               )
g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log')
                    )

g_bar.show()
# Out:
# <div>                            <div id="f427434b-0e56-42e1-abf4-812bb08f784a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f427434b-0e56-42e1-abf4-812bb08f784a")) {                    Plotly.newPlot(                        "f427434b-0e56-42e1-abf4-812bb08f784a",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[59,72,42,170,292,58,306,191,151,147,45,1585,310,107,1020,285,76,65,297,119,262,231,48,246,299,333,236,257,297,671,218,156,68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=Paid\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BOOKS_AND_REFERENCE","BUSINESS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[3,1,8,11,22,4,4,2,162,13,2,77,12,18,5,88,2,2,66,18,18,2,2,22,63,8,4,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_cleaner,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')
 
box.update_layout(yaxis=dict(type='log'))
 
box.show()
# Out:
# <div>                            <div id="80821592-5ecd-4865-a39c-143f6ddc21c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80821592-5ecd-4865-a39c-143f6ddc21c1")) {                    Plotly.newPlot(                        "80821592-5ecd-4865-a39c-143f6ddc21c1",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}\u003cbr\u003eInstalls=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_cleaner[df_apps_cleaner['Type'] == 'Paid']
box = px.box(df_paid_apps, 
             x='Category', 
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))
 
 
box.show()
# Out:
# <div>                            <div id="756fd7ff-5bee-427d-ab7a-de07e42d49b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("756fd7ff-5bee-427d-ab7a-de07e42d49b2")) {                    Plotly.newPlot(                        "756fd7ff-5bee-427d-ab7a-de07e42d49b2",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eRevenue_Estimate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","TOOLS","FAMILY","FAMILY","BUSINESS","BOOKS_AND_REFERENCE","FAMILY","FAMILY","FAMILY","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","GAME","PERSONALIZATION","FAMILY","FINANCE","SHOPPING","DATING","PERSONALIZATION","GAME","FAMILY","PRODUCTIVITY","FAMILY","MEDICAL","SPORTS","MEDICAL","PRODUCTIVITY","BUSINESS","PARENTING","LIFESTYLE","FAMILY","TOOLS","MAPS_AND_NAVIGATION","COMMUNICATION","PERSONALIZATION","COMMUNICATION","FAMILY","PERSONALIZATION","FAMILY","FAMILY","FAMILY","TOOLS","FAMILY","SPORTS","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","GAME","TOOLS","FAMILY","FAMILY","PERSONALIZATION","BOOKS_AND_REFERENCE","GAME","PERSONALIZATION","GAME","GAME","TOOLS","MEDICAL","FAMILY","TOOLS","TOOLS","PERSONALIZATION","GAME","COMMUNICATION","MEDICAL","SPORTS","PERSONALIZATION","COMMUNICATION","COMMUNICATION","PERSONALIZATION","TOOLS","PERSONALIZATION","PERSONALIZATION","PRODUCTIVITY","MEDICAL","FAMILY","TOOLS","TOOLS","BUSINESS","COMMUNICATION","FAMILY","PERSONALIZATION","PHOTOGRAPHY","MEDICAL","PERSONALIZATION","MEDICAL","COMMUNICATION","PRODUCTIVITY","BOOKS_AND_REFERENCE","TOOLS","WEATHER","FAMILY","FAMILY","MEDICAL","FAMILY","TOOLS","TOOLS","SPORTS","GAME","MEDICAL","PERSONALIZATION","PERSONALIZATION","NEWS_AND_MAGAZINES","COMMUNICATION","TOOLS","MEDICAL","FINANCE","FAMILY","PERSONALIZATION","PERSONALIZATION","MEDICAL","MEDICAL","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","FAMILY","FAMILY","GAME","PERSONALIZATION","FINANCE","TOOLS","PERSONALIZATION","GAME","GAME","GAME","FAMILY","FAMILY","PRODUCTIVITY","COMMUNICATION","SPORTS","SPORTS","FAMILY","MEDICAL","SPORTS","COMMUNICATION","LIFESTYLE","FAMILY","MEDICAL","MEDICAL","TOOLS","PRODUCTIVITY","FINANCE","HEALTH_AND_FITNESS","MEDICAL","PHOTOGRAPHY","FAMILY","FAMILY","PHOTOGRAPHY","SPORTS","ART_AND_DESIGN","FAMILY","PERSONALIZATION","PRODUCTIVITY","LIFESTYLE","HEALTH_AND_FITNESS","MEDICAL","MEDICAL","TOOLS","PRODUCTIVITY","GAME","TOOLS","MEDICAL","LIFESTYLE","GAME","MEDICAL","MEDICAL","TRAVEL_AND_LOCAL","BUSINESS","MEDICAL","MEDICAL","COMMUNICATION","PERSONALIZATION","GAME","TRAVEL_AND_LOCAL","GAME","SPORTS","MEDICAL","MEDICAL","FAMILY","MEDICAL","FINANCE","TOOLS","BOOKS_AND_REFERENCE","FAMILY","MEDICAL","MEDICAL","FINANCE","MEDICAL","MEDICAL","GAME","BUSINESS","TOOLS","FAMILY","MEDICAL","MEDICAL","PERSONALIZATION","PHOTOGRAPHY","SPORTS","MAPS_AND_NAVIGATION","PERSONALIZATION","GAME","BOOKS_AND_REFERENCE","EDUCATION","FAMILY","FAMILY","FAMILY","SOCIAL","MEDICAL","TOOLS","SPORTS","FAMILY","FAMILY","TOOLS","WEATHER","VIDEO_PLAYERS","MEDICAL","MEDICAL","TOOLS","GAME","PERSONALIZATION","MEDICAL","LIFESTYLE","MEDICAL","DATING","HEALTH_AND_FITNESS","MEDICAL","FAMILY","PRODUCTIVITY","EDUCATION","SPORTS","FAMILY","PERSONALIZATION","PERSONALIZATION","FAMILY","GAME","FINANCE","GAME","MEDICAL","FAMILY","MEDICAL","MEDICAL","TOOLS","TOOLS","TOOLS","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","FAMIL ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))
 
box.show()
# Out:
# <div>                            <div id="268d0b2a-b24a-4b0b-9563-084aa298bbd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("268d0b2a-b24a-4b0b-9563-084aa298bbd1")) {                    Plotly.newPlot(                        "268d0b2a-b24a-4b0b-9563-084aa298bbd1",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","TOOLS","FAMILY","FAMILY","BUSINESS","BOOKS_AND_REFERENCE","FAMILY","FAMILY","FAMILY","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","GAME","PERSONALIZATION","FAMILY","FINANCE","SHOPPING","DATING","PERSONALIZATION","GAME","FAMILY","PRODUCTIVITY","FAMILY","MEDICAL","SPORTS","MEDICAL","PRODUCTIVITY","BUSINESS","PARENTING","LIFESTYLE","FAMILY","TOOLS","MAPS_AND_NAVIGATION","COMMUNICATION","PERSONALIZATION","COMMUNICATION","FAMILY","PERSONALIZATION","FAMILY","FAMILY","FAMILY","TOOLS","FAMILY","SPORTS","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","GAME","TOOLS","FAMILY","FAMILY","PERSONALIZATION","BOOKS_AND_REFERENCE","GAME","PERSONALIZATION","GAME","GAME","TOOLS","MEDICAL","FAMILY","TOOLS","TOOLS","PERSONALIZATION","GAME","COMMUNICATION","MEDICAL","SPORTS","PERSONALIZATION","COMMUNICATION","COMMUNICATION","PERSONALIZATION","TOOLS","PERSONALIZATION","PERSONALIZATION","PRODUCTIVITY","MEDICAL","FAMILY","TOOLS","TOOLS","BUSINESS","COMMUNICATION","FAMILY","PERSONALIZATION","PHOTOGRAPHY","MEDICAL","PERSONALIZATION","MEDICAL","COMMUNICATION","PRODUCTIVITY","BOOKS_AND_REFERENCE","TOOLS","WEATHER","FAMILY","FAMILY","MEDICAL","FAMILY","TOOLS","TOOLS","SPORTS","GAME","MEDICAL","PERSONALIZATION","PERSONALIZATION","NEWS_AND_MAGAZINES","COMMUNICATION","TOOLS","MEDICAL","FINANCE","FAMILY","PERSONALIZATION","PERSONALIZATION","MEDICAL","MEDICAL","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","FAMILY","FAMILY","GAME","PERSONALIZATION","FINANCE","TOOLS","PERSONALIZATION","GAME","GAME","GAME","FAMILY","FAMILY","PRODUCTIVITY","COMMUNICATION","SPORTS","SPORTS","FAMILY","MEDICAL","SPORTS","COMMUNICATION","LIFESTYLE","FAMILY","MEDICAL","MEDICAL","TOOLS","PRODUCTIVITY","FINANCE","HEALTH_AND_FITNESS","MEDICAL","PHOTOGRAPHY","FAMILY","FAMILY","PHOTOGRAPHY","SPORTS","ART_AND_DESIGN","FAMILY","PERSONALIZATION","PRODUCTIVITY","LIFESTYLE","HEALTH_AND_FITNESS","MEDICAL","MEDICAL","TOOLS","PRODUCTIVITY","GAME","TOOLS","MEDICAL","LIFESTYLE","GAME","MEDICAL","MEDICAL","TRAVEL_AND_LOCAL","BUSINESS","MEDICAL","MEDICAL","COMMUNICATION","PERSONALIZATION","GAME","TRAVEL_AND_LOCAL","GAME","SPORTS","MEDICAL","MEDICAL","FAMILY","MEDICAL","FINANCE","TOOLS","BOOKS_AND_REFERENCE","FAMILY","MEDICAL","MEDICAL","FINANCE","MEDICAL","MEDICAL","GAME","BUSINESS","TOOLS","FAMILY","MEDICAL","MEDICAL","PERSONALIZATION","PHOTOGRAPHY","SPORTS","MAPS_AND_NAVIGATION","PERSONALIZATION","GAME","BOOKS_AND_REFERENCE","EDUCATION","FAMILY","FAMILY","FAMILY","SOCIAL","MEDICAL","TOOLS","SPORTS","FAMILY","FAMILY","TOOLS","WEATHER","VIDEO_PLAYERS","MEDICAL","MEDICAL","TOOLS","GAME","PERSONALIZATION","MEDICAL","LIFESTYLE","MEDICAL","DATING","HEALTH_AND_FITNESS","MEDICAL","FAMILY","PRODUCTIVITY","EDUCATION","SPORTS","FAMILY","PERSONALIZATION","PERSONALIZATION","FAMILY","GAME","FINANCE","GAME","MEDICAL","FAMILY","MEDICAL","MEDICAL","TOOLS","TOOLS","TOOLS","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","FAMILY","GAME"," ...
